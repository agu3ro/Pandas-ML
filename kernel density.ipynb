# %%
import pandas as pd
import numpy as np
# %matplotlib inline
my_df = pd.DataFrame(np.random.randn(500,4), columns=['A', 'B', 'C', 'D'])
my_df
# Out:
#             A         B         C         D
# 0    1.456908 -0.523938  0.733678  1.090536
# 1    2.747674 -2.269461  1.646008 -1.669339
# 2    1.650197 -2.052708  0.144789 -0.975608
# 3    0.529323 -1.645182 -0.237073 -0.012088
# 4    0.349080  0.298523  0.195057 -1.925274
# ..        ...       ...       ...       ...
# 495 -2.142836  0.455420  1.274563  0.237495
# 496 -0.630987 -0.658451 -2.099196 -0.971637
# 497  1.072177  0.328167 -1.117815  0.276164
# 498  2.311055 -1.642776  0.641290 -0.764150
# 499 -0.764890  0.108856 -0.533977 -0.214939
#
# [500 rows x 4 columns]

# %%
# Kernel Density plot (with scipy) 
my_df.plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
# Density Plot (not much difference between these two)
my_df.plot(kind='density', title='techies9', grid=True, alpha=0.6, lw=3)
# Out:
# <Axes: title={'center': 'techies9'}, ylabel='Density'>
