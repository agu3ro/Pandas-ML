# %%
import pandas as pd 
import numpy as np
# %matplotlib inline

# %%
my_df = pd.DataFrame(np.random.randn(500,4), columns=['A', 'B', 'C', 'D'])
my_df.plot(kind='box',)
# Out:
# <Axes: >

# %%
# everything (cant add legend)
my_df.plot(kind='box', figsize=(10,5), cmap='bwr', grid=True, title = 'lol')
# Out:
# <Axes: title={'center': 'lol'}>

# %%
# Other way
my_df.plot.box()
# Out:
# <Axes: >
