# %%
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
my_df = pd.DataFrame(np.random.randn(100,4), columns = ["Mon","Tue","Wed","Thr"])
my_df
# Out:
#          Mon       Tue       Wed       Thr
# 0   0.627481 -3.052344  0.476786 -0.008758
# 1   1.753145  0.165490 -0.682203  0.625721
# 2   0.780273 -0.433265 -1.743686 -0.233136
# 3  -0.196449 -0.148830 -0.117929 -0.297200
# 4   0.929552  0.222192  0.636189  0.591870
# ..       ...       ...       ...       ...
# 95 -1.131474  0.915588 -0.719388  0.807877
# 96 -0.749546  1.250458  1.505159 -0.733914
# 97 -0.089684  1.501814  0.565177 -0.880465
# 98  0.007807 -0.916351 -0.501287  1.099662
# 99  1.042761 -0.660387 -0.735331  1.049896
#
# [100 rows x 4 columns]

# %%
# Histogram
my_df["Wed"].hist()
# Out:
# <Axes: >

# %%
# Histogram with smaller bins
my_df["Wed"].hist(bins=50)
# Out:
# <Axes: >

# %%
# Another way without grid bars
my_df["Wed"].plot(kind='hist', bins=50)
# Out:
# <Axes: ylabel='Frequency'>

# %%
# без решеточки (w/o grid)
my_df['Wed'].hist(bins=50, grid=False)
# Out:
# <Axes: >

# %%
# LEGEND (top right shows all columns' results)
my_df['Wed'].hist(bins=50, grid=False, legend=True)
# Out:
# <Axes: >
