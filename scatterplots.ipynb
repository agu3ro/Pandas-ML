# %%
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
my_df = pd.DataFrame(np.random.randn(500,4), columns=['A', 'B', 'C', 'D'])
my_df
# Out:
#             A         B         C         D
# 0   -0.184084 -0.801903  1.299469  0.773081
# 1    1.965628 -1.234331 -0.337013 -1.170953
# 2   -0.753862 -0.948567 -3.434484  2.143059
# 3    1.106979  0.099241 -1.268032 -1.224961
# 4   -1.010507  0.903440  1.076962  0.904420
# ..        ...       ...       ...       ...
# 495  0.892460  0.213971  0.424953 -0.457888
# 496  0.029661 -0.180481  0.828296 -1.312451
# 497  0.098545 -1.105711 -0.437642 -1.151749
# 498 -0.485177  1.690447 -0.688686 -2.066458
# 499  0.908120 -1.643161  1.422106 -1.393831
#
# [500 rows x 4 columns]

# %%
# Scatter plot
my_df.plot(kind='scatter', x='A', y='B', c='C')
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %%
# C MAP (colors https://matplotlib.org/stable/users/explain/colors/colormaps.html) + some stuff from other vid
my_df.plot(kind='scatter', x='A', y='B', c='C', cmap='copper', alpha=0.6, figsize=(10,5))
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %%
# SIZE instead of figsize (s)
my_df.plot(kind='scatter', x='A', y='B', s=my_df['C']*25, alpha=0.6)
# Out:
# C:\Users\artem\c\mydata\vint\Lib\site-packages\matplotlib\collections.py:996: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
# <Axes: xlabel='A', ylabel='B'>
