# %%
import pandas as pd
import numpy as np
# %matplotlib inline
my_df = pd.DataFrame(np.random.randn(500,4), columns=['A', 'B', 'C', 'D'])
my_df
# Out:
#             A         B         C         D
# 0   -0.508379 -1.242754 -0.041343  0.238168
# 1    1.021821 -0.582597 -0.393265  2.213588
# 2    1.454322 -1.124902 -0.031881 -0.371028
# 3   -0.425886 -0.659931 -1.739155 -0.279626
# 4   -0.398708 -0.868289 -0.309373  0.357582
# ..        ...       ...       ...       ...
# 495 -0.758219  0.139761 -0.110807  0.555955
# 496  0.789730  1.357041  1.217681  1.469178
# 497  0.270843 -0.027306  0.381379  0.028266
# 498  1.462978 -0.924253 -0.014425  0.115004
# 499 -0.533499 -0.900109  1.562185 -0.716599
#
# [500 rows x 4 columns]

# %%
my_df.plot(kind='hexbin', x='A', y='B')
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %%
# Gridsize + other things
my_df.plot(kind='hexbin', x='A', y='B', gridsize=10, cmap='YlGn', grid=True, title='techies8')
# Out:
# <Axes: title={'center': 'techies8'}, xlabel='A', ylabel='B'>

# %%
# other way
my_df.plot.hexbin(x='A', y='B', gridsize=10)
# Out:
# <Axes: xlabel='A', ylabel='B'>
